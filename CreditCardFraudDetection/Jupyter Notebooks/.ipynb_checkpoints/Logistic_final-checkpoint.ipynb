# %% [markdown]
# ## Insert here your data for testing (CSV format, should be in the same folder of the Notebook):

# %%
test= 'final.csv'#'filename.csv'

# %% [markdown]
# ## Loading data, to be run

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

data= pd.read_csv("creditcard_train.csv")
# data=pd.read_csv('creditcard_train.csv')
data=data.drop_duplicates(keep=False)
  
x=data.drop(['Class'],axis=1)
y=data.Class
X_train1,X_test,y_train1,y_test=train_test_split(x,y,test_size=0.2,random_state=0,stratify=y)

# %% [markdown]
# ## Part 1: all the dataset

# %%
model = LogisticRegression(max_iter=1000,random_state=0)
model.fit(X_train1, y_train1)
y_pred = model.predict(X_test)

# %%
print('Accuracy:',accuracy_score(y_test,y_pred))
print('Precision:',metrics.precision_score(y_test,y_pred))
print('Recall:',metrics.recall_score(y_test,y_pred))
cm = confusion_matrix(y_test, y_pred)
df_cm = pd.DataFrame(cm, index = (0, 1), columns = (0, 1))
plt.figure(figsize = (10,7))
sns.set(font_scale=1.4)
sns.heatmap(df_cm, annot=True, fmt='g')
print("Test Data Accuracy: %0.4f" % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9992943726216578
# Precision: 0.8070175438596491
# Recall: 0.7301587301587301
# Test Data Accuracy: 0.9993

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %% [markdown]
# We try to use weights on our classes in order to compensate the imbalance in the dataset. To do this, we use a function of Python library which, quoting library description "uses the values of y to automatically adjust weights inversely proportional to class frequencies in the input data as n_samples / (n_classes * np.bincount(y))."

# %%
model = LogisticRegression(max_iter=1000,class_weight="balanced",random_state=0)
model.fit(X_train1, y_train1)
y_pred = model.predict(X_test)

# %%
print('Accuracy:',accuracy_score(y_test,y_pred))
print('Precision:',metrics.precision_score(y_test,y_pred))
print('Recall:',metrics.recall_score(y_test,y_pred))
cm = confusion_matrix(y_test, y_pred)
df_cm = pd.DataFrame(cm, index = (0, 1), columns = (0, 1))
plt.figure(figsize = (10,7))
sns.set(font_scale=1.4)
sns.heatmap(df_cm, annot=True, fmt='g')
print("Test Data Accuracy: %0.4f" % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9577379602328571
# Precision: 0.03352601156069364
# Recall: 0.9206349206349206
# Test Data Accuracy: 0.9577

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %% [markdown]
# ## Part 2: undersample the dataset

# %%
train=pd.concat([X_train1,y_train1],axis=1).sample(frac=1)
count=317
nofraud_frame1 = train.loc[data.Class == 0][:int(np.round((len(train)-count)*0.2))]
fraud_frame1 = train.loc[data.Class == 1][:int(np.round(count))]
train = pd.concat([fraud_frame1, nofraud_frame1]).sample(frac=1)
X_train=train.drop(['Class'],axis=1)
y_train=train.Class

# %%
model = LogisticRegression(max_iter=1000,class_weight="balanced",random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
print('Accuracy:',accuracy_score(y_test,y_pred))
print('Precision:',metrics.precision_score(y_test,y_pred))
print('Recall:',metrics.recall_score(y_test,y_pred))
cm = confusion_matrix(y_test, y_pred)
df_cm = pd.DataFrame(cm, index = (0, 1), columns = (0, 1))
plt.figure(figsize = (10,7))
sns.set(font_scale=1.4)
sns.heatmap(df_cm, annot=True, fmt='g')
print("Test Data Accuracy: %0.4f" % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9574103475214838
# Precision: 0.03327596098680436
# Recall: 0.9206349206349206
# Test Data Accuracy: 0.9574

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %% [markdown]
# ## Part 3: drop irrelevant features

# %%
train=pd.concat([X_train1,y_train1],axis=1).sample(frac=1)
count=317
nofraud_frame1 = train.loc[data.Class == 0][:int(np.round((len(train)-count)*0.2))]
fraud_frame1 = train.loc[data.Class == 1][:int(np.round(count))]
train = pd.concat([fraud_frame1, nofraud_frame1]).sample(frac=1)
X_train=train.drop(['Class'],axis=1)
X_trainn = X_train[['V14', 'V3','V17', 'V12','V10','V11','V4','V1']]
y_trainn=train.Class

X_testt = X_test[['V14', 'V3','V17', 'V12','V10','V11','V4','V1']]

# %%
model = LogisticRegression(max_iter=1000,class_weight="balanced",random_state=0)
model.fit(X_trainn, y_trainn)
y_pred = model.predict(X_testt)

# %%
print('Accuracy:',accuracy_score(y_test,y_pred))
print('Precision:',metrics.precision_score(y_test,y_pred))
print('Recall:',metrics.recall_score(y_test,y_pred))
cm = confusion_matrix(y_test, y_pred)
df_cm = pd.DataFrame(cm, index = (0, 1), columns = (0, 1))
plt.figure(figsize = (10,7))
sns.set(font_scale=1.4)
sns.heatmap(df_cm, annot=True, fmt='g')
print("Test Data Accuracy: %0.4f" % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9740429928681232
# Precision: 0.05355493998153278
# Recall: 0.9206349206349206
# Test Data Accuracy: 0.9740

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %% [markdown]
# ## Part 4: oversample the dataset

# %%
count=317
data_shuffle = data.sample(frac=1)
fraud_frame = data_shuffle.loc[data.Class == 1][:int(np.round(count*0.8))]
nofraud_frame1 = data_shuffle.loc[data.Class == 0][:int(np.round((len(data_shuffle)-count)*0.8))]
num=int(np.log2((len(nofraud_frame1))/len(fraud_frame)))
for i in range(num-3):
    fraud_frame=pd.concat([fraud_frame,fraud_frame])
train = pd.concat([fraud_frame, nofraud_frame1]).sample(frac=1)
X_train=train.drop(['Class'],axis=1)
y_train=train.Class

# %%
model = LogisticRegression(max_iter=1000,class_weight="balanced")
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
print('Accuracy:',accuracy_score(y_test,y_pred))
print('Precision:',metrics.precision_score(y_test,y_pred))
print('Recall:',metrics.recall_score(y_test,y_pred))
cm = confusion_matrix(y_test, y_pred)
df_cm = pd.DataFrame(cm, index = (0, 1), columns = (0, 1))
plt.figure(figsize = (10,7))
sns.set(font_scale=1.4)
sns.heatmap(df_cm, annot=True, fmt='g')
print("Test Data Accuracy: %0.4f" % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9631309694816159
# Precision: 0.03825857519788918
# Recall: 0.9206349206349206
# Test Data Accuracy: 0.9631

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %% [markdown]
# ## Part 5: drop irrelevant features

# %%
train = pd.concat([fraud_frame, nofraud_frame1]).sample(frac=1)
x=train.drop(['Class'],axis=1)
X_train=x[['V4','V11','V12','V14','V1','V3','V10','V17']]
y_train=train.Class

X=X_test.copy()
X=X[['V4','V11','V12','V14','V1','V3','V10','V17']]

# %%
model = LogisticRegression(max_iter=1000,class_weight="balanced",random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X)

# %%
print('Accuracy:',accuracy_score(y_test,y_pred))
print('Precision:',metrics.precision_score(y_test,y_pred))
print('Recall:',metrics.recall_score(y_test,y_pred))
cm = confusion_matrix(y_test, y_pred)
df_cm = pd.DataFrame(cm, index = (0, 1), columns = (0, 1))
plt.figure(figsize = (10,7))
sns.set(font_scale=1.4)
sns.heatmap(df_cm, annot=True, fmt='g')
print("Test Data Accuracy: %0.4f" % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9736901791789522
# Precision: 0.0528714676390155
# Recall: 0.9206349206349206
# Test Data Accuracy: 0.9737

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %% [markdown]
# ## Final results

# %%
data_test = pd.read_csv(test)
X_test=data_test.drop(['Class'],axis=1)
X_test = X_test[['V14','V3','V17','V12','V10','V11','V4','V1']]
y_test=data_test.Class

nofraud_frame1 = data.loc[data.Class == 0][:int(np.round((len(data))*0.2))]
fraud_frame1 = data.loc[data.Class == 1]
train = pd.concat([fraud_frame1, nofraud_frame1]).sample(frac=1)
y_train=train.Class
X_train = train[['V14','V3','V17','V12','V10','V11','V4','V1']]

# %%
model = LogisticRegression(max_iter=1000,class_weight="balanced",random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
print('Accuracy:',accuracy_score(y_test,y_pred))
print('Precision:',metrics.precision_score(y_test,y_pred))
print('Recall:',metrics.recall_score(y_test,y_pred))
cm = confusion_matrix(y_test, y_pred)
df_cm = pd.DataFrame(cm, index = (0, 1), columns = (0, 1))
plt.figure(figsize = (10,7))
sns.set(font_scale=1.4)
sns.heatmap(df_cm, annot=True, fmt='g')
print("Test Data Accuracy: %0.4f" % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.976081574914535
# Precision: 0.06069094304388422
# Recall: 0.8843537414965986
# Test Data Accuracy: 0.9761

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %%
np.savetxt('LR_predictions.txt',y_pred, fmt = '%i', newline = '\n')
